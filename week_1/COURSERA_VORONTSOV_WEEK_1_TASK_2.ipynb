# %%
import pandas as pd

# %%
data = pd.read_csv('titanic.csv', index_col = 'PassengerId')

# %%
data[:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# 6                                             Moran, Mr. James    male  NaN
# ...

# %%
data.shape
# Out:
# (891, 11)

# %%
new_data = data.drop(['Name', 'Parch', 'Cabin', 'Embarked', 'Ticket', 'SibSp'], axis = 1)

# %%
new_data[:10]
# Out:
#              Survived  Pclass     Sex  Age     Fare
# PassengerId
# 1                   0       3    male   22   7.2500
# 2                   1       1  female   38  71.2833
# 3                   1       3  female   26   7.9250
# 4                   1       1  female   35  53.1000
# 5                   0       3    male   35   8.0500
# 6                   0       3    male  NaN   8.4583
# 7                   0       1    male   54  51.8625
# 8                   0       3    male    2  21.0750
# 9                   1       3  female   27  11.1333
# 10                  1       2  female   14  30.0708

# %%
import math

# %%
for i in range (891):
    if math.isnan(new_data['Age'][i + 1]) == True:
        new_data.drop([i + 1], axis = 0, inplace = True )

# %%
new_data[:10]
# Out:
#              Survived  Pclass     Sex  Age     Fare
# PassengerId
# 1                   0       3    male   22   7.2500
# 2                   1       1  female   38  71.2833
# 3                   1       3  female   26   7.9250
# 4                   1       1  female   35  53.1000
# 5                   0       3    male   35   8.0500
# 7                   0       1    male   54  51.8625
# 8                   0       3    male    2  21.0750
# 9                   1       3  female   27  11.1333
# 10                  1       2  female   14  30.0708
# 11                  1       3  female    4  16.7000

# %%
Y = new_data['Survived']

# %%
new_data.replace('male', 1, inplace = True)

# %%
new_data[:10]
# Out:
#              Survived  Pclass     Sex  Age     Fare
# PassengerId
# 1                   0       3       1   22   7.2500
# 2                   1       1  female   38  71.2833
# 3                   1       3  female   26   7.9250
# 4                   1       1  female   35  53.1000
# 5                   0       3       1   35   8.0500
# 7                   0       1       1   54  51.8625
# 8                   0       3       1    2  21.0750
# 9                   1       3  female   27  11.1333
# 10                  1       2  female   14  30.0708
# 11                  1       3  female    4  16.7000

# %%
new_data.replace('female', 0, inplace = True)

# %%
new_data[:10]
# Out:
#              Survived  Pclass  Sex  Age     Fare
# PassengerId
# 1                   0       3    1   22   7.2500
# 2                   1       1    0   38  71.2833
# 3                   1       3    0   26   7.9250
# 4                   1       1    0   35  53.1000
# 5                   0       3    1   35   8.0500
# 7                   0       1    1   54  51.8625
# 8                   0       3    1    2  21.0750
# 9                   1       3    0   27  11.1333
# 10                  1       2    0   14  30.0708
# 11                  1       3    0    4  16.7000

# %%
X = new_data.drop(['Survived'], axis = 1)

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state = 241)
clf.fit(X, Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=241, splitter='best')

# %%
importances = clf.feature_importances_

# %%
print importances
# Out:
# [ 0.14000522  0.30051221  0.2560461   0.30343647]
